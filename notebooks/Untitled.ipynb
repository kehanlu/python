# %%
import requests
requests.get("https://moodle.ntust.edu.tw/",cookies={"MoodleSessionntustMoodle":"bs65un9k27v91bm0jrk5se0856"}).text
# Out:
# '<!DOCTYPE html>\n<html  dir="ltr" lang="zh-tw" xml:lang="zh-tw" class="no-js">\n<head>\n    <title>【國立臺灣科技大學數位學習平台】</title>\n    <link rel="shortcut icon" href="https://moodle.ntust.edu.tw/theme/image.php/essential/theme/1544070055/favicon"/>\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<meta name="keywords" content="moodle, 【國立臺灣科技大學數位學習平台】" />\n<link rel="stylesheet" type="text/css" href="https://moodle.ntust.edu.tw/theme/yui_combo.php?rollup/3.17.2/yui-moodlesimple-min.css" /><script id="firstthemesheet" type="text/css">/** Required in order to fix style inclusion problems in IE with YUI **/</script><link rel="stylesheet" type="text/css" href="https://moodle.ntust.edu.tw/theme/styles.php/essential/1544070055/all" />\n<script type="text/javascript">\n//<![CDATA[\nvar M = {}; M.yui = {};\nM.pageloadstarttime = new Date();\nM.cfg = {"wwwroot":"https:\\/\\/moodle.ntust.edu.tw","sesskey":"8SC0QdDcxn","loadingicon":"https:\\/\\/moodle.ntust.edu.tw\\/theme
# ...
